# %%
import os
import shutil

# Lista completa de arquivos que precisam de correção.
# Os caminhos são relativos à pasta 'src/main/java/'.
files_to_fix = [
    "com/tacz/guns/api/TimelessAPI.java",
    "com/tacz/guns/api/item/builder/GunItemBuilder.java",
    "com/tacz/guns/api/item/gun/AbstractGunItem.java",
    "com/tacz/guns/api/item/nbt/GunItemDataAccessor.java",
    "com/tacz/guns/item/AmmoBoxItem.java",
    "com/tacz/guns/item/AmmoItem.java",
    "com/tacz/guns/item/AttachmentItem.java",
    "com/tacz/guns/item/GunSmithTableItem.java",
    "com/tacz/guns/item/ModernKineticGunItem.java",
    "com/tacz/guns/item/ModernKineticGunScriptAPI.java",
    "com/tacz/guns/item/TargetMinecartItem.java",
    "com/tacz/guns/client/gui/GunSmithTableScreen.java",
    "com/tacz/guns/client/gui/GunRefitScreen.java",
    "com/tacz/guns/client/gui/components/refit/GunPropertyDiagrams.java",
    "com/tacz/guns/client/gui/overlay/GunHudOverlay.java",
    "com/tacz/guns/client/gui/overlay/HeatBarOverlay.java",
    "com/tacz/guns/client/renderer/item/AnimateGeoItemRenderer.java",
    "com/tacz/guns/client/renderer/item/AmmoItemRenderer.java",
    "com/tacz/guns/client/renderer/item/GunItemRendererWrapper.java",
    "com/tacz/guns/client/renderer/item/GunSmithTableItemRenderer.java",
    "com/tacz/guns/client/renderer/block/TargetRenderer.java",
    "com/tacz/guns/client/renderer/entity/EntityBulletRenderer.java",
    "com/tacz/guns/client/renderer/entity/TargetMinecartRenderer.java",
    "com/tacz/guns/client/model/functional/MuzzleFlashRender.java",
    "com/tacz/guns/client/model/functional/ShellRender.java",
    "com/tacz/guns/entity/EntityKineticBullet.java",
    "com/tacz/guns/entity/TargetMinecart.java",
    "com/tacz/guns/entity/shooter/LivingEntityAim.java",
    "com/tacz/guns/entity/shooter/LivingEntityBolt.java",
    "com/tacz/guns/entity/shooter/LivingEntityCrawl.java",
    "com/tacz/guns/entity/shooter/LivingEntityDrawGun.java",
    "com/tacz/guns/entity/shooter/LivingEntityFireSelect.java",
    "com/tacz/guns/entity/shooter/LivingEntityMelee.java",
    "com/tacz/guns/entity/shooter/LivingEntityReload.java",
    "com/tacz/guns/entity/shooter/LivingEntityShoot.java",
    "com/tacz/guns/entity/shooter/LivingEntitySpeedModifier.java",
    "com/tacz/guns/entity/sync/core/SyncedEntityData.java",
    "com/tacz/guns/entity/sync/core/SyncedDataKey.java",
    "com/tacz/guns/network/NetworkHandler.java",
    "com/tacz/guns/network/message/ClientMessageCraft.java",
    "com/tacz/guns/network/message/ClientMessageLaserColor.java",
    "com/tacz/guns/network/message/ClientMessagePlayerAim.java",
    "com/tacz/guns/network/message/ClientMessagePlayerCrawl.java",
    "com/tacz/guns/network/message/ClientMessagePlayerShoot.java",
    "com/tacz/guns/network/message/ClientMessageRefitGun.java",
    "com/tacz/guns/network/message/ClientMessageSyncBaseTimestamp.java",
    "com/tacz/guns/network/message/ClientMessageUnloadAttachment.java",
    "com/tacz/guns/network/message/event/ServerMessageGunFireSelect.java",
    "com/tacz/guns/network/message/event/ServerMessageGunHurt.java",
    "com/tacz/guns/network/message/event/ServerMessageGunKill.java",
    "com/tacz/guns/network/message/event/ServerMessageGunMelee.java",
    "com/tacz/guns/network/message/handshake/ServerMessageSyncedEntityDataMapping.java",
    "com/tacz/guns/network/message/ServerMessageSound.java",
    "com/tacz/guns/network/message/ServerMessageSyncGunPack.java",
    "com/tacz/guns/network/message/ServerMessageUpdateEntityData.java",
    "com/tacz/guns/resource/modifier/AttachmentCacheProperty.java",
    "com/tacz/guns/resource/modifier/custom/AimInaccuracyModifier.java",
    "com/tacz/guns/resource/modifier/custom/AmmoSpeedModifier.java",
    "com/tacz/guns/resource/modifier/custom/ArmorIgnoreModifier.java",
    "com/tacz/guns/resource/modifier/custom/EffectiveRangeModifier.java",
    "com/tacz/guns/resource/modifier/custom/ExplosionModifier.java",
    "com/tacz/guns/resource/modifier/custom/ExtraMovementModifier.java",
    "com/tacz/guns/resource/modifier/custom/HeadShotModifier.java",
    "com/tacz/guns/resource/modifier/custom/IgniteModifier.java",
    "com/tacz/guns/resource/modifier/custom/InaccuracyModifier.java",
    "com/tacz/guns/resource/modifier/custom/KnockbackModifier.java",
    "com/tacz/guns/resource/modifier/custom/PierceModifier.java",
    "com/tacz/guns/resource/modifier/custom/RecoilModifier.java",
    "com/tacz/guns/resource/modifier/custom/RpmModifier.java",
    "com/tacz/guns/resource/modifier/custom/SilenceModifier.java",
    "com/tacz/guns/resource/modifier/custom/WeightModifier.java",
    "com/tacz/guns/crafting/GunSmithTableMenu.java",
    "com/tacz/guns/crafting/GunSmithTableRecipe.java",
    "com/tacz/guns/crafting/GunSmithTableSerializer.java",
    "com/tacz/guns/crafting/result/RawGunTableResult.java",
    "com/tacz/guns/resource/serialize/GunSmithTableResultSerializer.java",
    "com/tacz/guns/GunMod.java",
    "com/tacz/guns/client/event/CameraSetupEvent.java",
    "com/tacz/guns/client/event/PlayerHurtByGunEvent.java",
    "com/tacz/guns/client/event/RenderCrosshairEvent.java",
    "com/tacz/guns/client/event/TooltipEvent.java",
    "com/tacz/guns/client/init/ClientSetupEvent.java",
    "com/tacz/guns/client/init/ModContainerScreen.java",
    "com/tacz/guns/client/init/ModEntitiesRender.java",
    "com/tacz/guns/client/input/ConfigKey.java",
    "com/tacz/guns/client/input/ReloadKey.java",
    "com/tacz/guns/client/input/ShootKey.java",
    "com/tacz/guns/client/particle/BulletHoleParticle.java",
    "com/tacz/guns/client/sound/SoundPlayManager.java",
    "com/tacz/guns/client/tooltip/ClientAttachmentItemTooltip.java",
    "com/tacz/guns/compat/jei/GunModPlugin.java",
    "com/tacz/guns/compat/jei/entry/AttachmentQueryEntry.java",
    "com/tacz/guns/event/ammo/DestroyGlassBlock.java",
    "com/tacz/guns/event/SyncedEntityDataEvent.java",
    "com/tacz/guns/init/CapabilityRegistry.java",
    "com/tacz/guns/init/CommonRegistry.java",
    "com/tacz/guns/mixin/client/GameRendererMixin.java",
    "com/tacz/guns/mixin/client/MouseHandlerMixin.java",
    "com/tacz/guns/mixin/common/LivingEntityMixin.java",
    "com/tacz/guns/util/block/ProjectileExplosion.java",
]

# Diretório raiz onde os pacotes Java começam (ex: 'src/main/java')
source_root = os.path.join('src', 'main', 'java')

# Nome da pasta de destino para onde os arquivos serão copiados
destination_folder = 'Files To Fix'

# Cria a pasta de destino se ela não existir
os.makedirs(destination_folder, exist_ok=True)
print(f"Pasta de destino '{destination_folder}' foi criada ou já existe.")

# Contadores para o relatório final
files_copied = 0
files_not_found = 0
not_found_list = []

# Itera sobre a lista de arquivos e os copia
for file_path in files_to_fix:
    # Constrói o caminho completo do arquivo de origem
    # os.path.join lida com os separadores de diretório corretos para o seu sistema operacional
    source_file = os.path.join(source_root, *file_path.split('/'))
    
    try:
        # Verifica se o arquivo de origem existe antes de copiar
        if os.path.exists(source_file):
            shutil.copy(source_file, destination_folder)
            print(f" -> Copiado: {source_file}")
            files_copied += 1
        else:
            print(f" [!] Arquivo não encontrado: {source_file}")
            files_not_found += 1
            not_found_list.append(source_file)
            
    except Exception as e:
        print(f" [X] Erro ao copiar {source_file}: {e}")

# Imprime um relatório final
print("\n" + "="*30)
print("RELATÓRIO DA CÓPIA DE ARQUIVOS")
print("="*30)
print(f"Arquivos copiados com sucesso: {files_copied}")
print(f"Arquivos não encontrados: {files_not_found}")

if not_found_list:
    print("\nLista de arquivos não encontrados:")
    for f in not_found_list:
        print(f"- {f}")
        
print("\nProcesso concluído!")
